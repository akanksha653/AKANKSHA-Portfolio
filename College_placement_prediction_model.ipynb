# %% [markdown]
# <a href="https://colab.research.google.com/github/akanksha653/AKANKSHA-Portfolio/blob/main/College_placement_prediction_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🎓📊 College Placements Predictor – AI Model 🚀📈

# %% [markdown]
# #### 📚Required Libraries

# %%
import pandas as pd
import requests

# %%
New_data = pd.read_csv("/content/filtered_output.csv")

# %% [markdown]
# #####  🔍i already perform Eda and extract required columns for my project and convert into csv, i used methods for EDA such as - column extraction using pd.DataFrame , columns name changing using New_data.shape , , isnull() , data.duplicated() , info() , rename() and etc etc.

# %%
New_data.head() # we use this method to see our data
# Out:
#    Unnamed: 0                                     Stream  Cgpa Internships  \
# 0           0                     Mechanical Engineering  7.37          No
# 1           1  Electronics and Communication Engineering  9.35          No
# 2           2                     Information Technology  7.84          No
# 3           3                   Computer Science in AIML  7.87         Yes
# 4           4           Computer Science and Engineering  9.26         Yes
#
#   Project   Placement
# 0      No  Not Placed
# 1     Yes  Not Placed
# 2     Yes      Placed
# 3     Yes  Not Placed
# 4     Yes  Not Placed

# %%
 New_data = New_data.iloc[:,1:] # we remove unnamed:0 from out dataset
 New_data.head()
# Out:
#                                       Stream  Cgpa Internships Project  \
# 0                     Mechanical Engineering  7.37          No      No
# 1  Electronics and Communication Engineering  9.35          No     Yes
# 2                     Information Technology  7.84          No     Yes
# 3                   Computer Science in AIML  7.87         Yes     Yes
# 4           Computer Science and Engineering  9.26         Yes     Yes
#
#     Placement
# 0  Not Placed
# 1  Not Placed
# 2      Placed
# 3  Not Placed
# 4  Not Placed

# %% [markdown]
# #### 📝 Now we change categorical values of columns in numerical so we can train our model

# %%
# Keep it strictly 1 and 0 for Logistic Regression
New_data["Placement"] = New_data["Placement"].map({"Placed": 1, "Not Placed": 0})

# Drop rows with missing values instead of using -1
New_data.dropna(subset=["Placement"], inplace=True)

# %%
New_data["Internships"] = New_data["Internships"].map({"Yes": 1, "No": 0}).fillna(-1)
New_data["Project"] = New_data["Project"].map({"Yes": 1, "No": 0}).fillna(-1)

# %%
New_data.head()
# Out:
#                                       Stream  Cgpa  Internships  Project  \
# 0                     Mechanical Engineering  7.37            0      0.0
# 1  Electronics and Communication Engineering  9.35            0      1.0
# 2                     Information Technology  7.84            0      1.0
# 3                   Computer Science in AIML  7.87            1      1.0
# 4           Computer Science and Engineering  9.26            1      1.0
#
#    Placement
# 0       -1.0
# 1       -1.0
# 2        1.0
# 3       -1.0
# 4       -1.0

# %%
New_data["Stream"].value_counts() # using these we can see our column data value count that how many uniques data we have and thier counts
# Out:
# Stream
# Computer Science and Engineering                81
# Electronics and Communication Engineering       62
# Information Technology                          41
# Electrical Engineering                          37
# Mechanical Engineering                          32
# Civil Engineering                               27
# Electrical and Electronics Engineering          27
# Computer Science in Data Science                23
# Computer Science and Design                     23
# Computer Science in AIML                        22
# Chemical Engineering                            19
# Electronics and Communication and Engineeing     3
# Production Engineering                           1
# IMsc Maths and Computing                         1
# Electronics Engineering                          1
# Electronic Engineering                           1
# Name: count, dtype: int64

# %% [markdown]
# #### Here i found that there many uniques values so i have to use column tranformation to convert it for training but i don't want to use columns transformation so i though why not give them number so our model identify easily.

# %%
stream_id_map = {
    "Computer Science and Engineering": 1,
    "Electronics and Communication Engineering": 2,
    "Information Technology": 3,
    "Electrical Engineering": 4,
    "Mechanical Engineering": 5,
    "Civil Engineering": 6,
    "Electrical and Electronics Engineering": 7,
    "Computer Science in Data Science": 8,
    "Computer Science and Design": 9,
    "Computer Science in AIML": 10
}

New_data["Stream_ID"] = New_data["Stream"].map(stream_id_map)

# %%
New_data.head()
# Out:
#                                       Stream  Cgpa  Internships  Project  \
# 0                     Mechanical Engineering  7.37            0      0.0
# 1  Electronics and Communication Engineering  9.35            0      1.0
# 2                     Information Technology  7.84            0      1.0
# 3                   Computer Science in AIML  7.87            1      1.0
# 4           Computer Science and Engineering  9.26            1      1.0
#
#    Placement  Stream_ID
# 0       -1.0        5.0
# 1       -1.0        2.0
# 2        1.0        3.0
# 3       -1.0       10.0
# 4       -1.0        1.0

# %%
 New_data = New_data.iloc[:,1:] # here we agin remove stream column because we create stream_Id which will go for training
 New_data.head()
# Out:
#    Cgpa  Internships  Project  Placement  Stream_ID
# 0  7.37            0      0.0       -1.0        5.0
# 1  9.35            0      1.0       -1.0        2.0
# 2  7.84            0      1.0        1.0        3.0
# 3  7.87            1      1.0       -1.0       10.0
# 4  9.26            1      1.0       -1.0        1.0

# %%
# Move column to a specific position
column_to_move = "Stream_ID"
desired_position = 0  # index starts from 0

# Reorder columns
cols = list(New_data.columns)
cols.insert(desired_position, cols.pop(cols.index(column_to_move)))
New_data = New_data[cols]

# %%
# New way (Pandas 3.0 compatible):
New_data["Stream_ID"] = New_data["Stream_ID"].fillna(0)
New_data.sample(10)
# Out:
# /tmp/ipython-input-4213526727.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   New_data["Stream_ID"].fillna(0, inplace=True)
#      Stream_ID  Cgpa  Internships  Project  Placement
# 31         1.0  7.80            1      1.0       -1.0
# 369        4.0  7.24            0      1.0        1.0
# 141        4.0  9.48            0      1.0        1.0
# 206        9.0  9.21            1      0.0       -1.0
# 199        1.0  8.82            1      0.0       -1.0
# 307        5.0  8.43            0      1.0       -1.0
# 57         9.0  8.58            1      1.0        1.0
# 388        9.0  8.30            1     -1.0        1.0
# 380        1.0  6.50            1      1.0       -1.0
# 316        2.0  7.07            1      1.0       -1.0

# %%
New_data["Internships"] = New_data["Internships"].astype(float)  # we convert it to float so our model training will go smooth

# %% [markdown]
# ## 📊 We use Matplotib and Seaborn for Data visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.scatter(New_data["Stream_ID"] ,New_data["Cgpa"], c  = New_data["Placement"])

# %%
plt.scatter(New_data["Internships"],New_data["Project"] , c  = New_data["Placement"])

# %%
sns.pairplot(New_data,  hue = "Placement") # with seaborn we can see each plot

# %% [markdown]
# ###  🛠️ Here we divide our data in x and y

# %%
x = New_data.iloc[: , 0:4]
y = New_data.iloc[: , -1]

# %%
New_data.head(1)
# Out:
#    Stream_ID  Cgpa  Internships  Project  Placement
# 0        5.0  7.37          0.0      0.0       -1.0

# %%
# x.head(1)
x.shape
# Out:
# (401, 4)

# %%
#y.head()
y.shape
# Out:
# (401,)

# %% [markdown]
# ## 🧠TRAIN TEST SPLIT

# %% [markdown]
# we use sicklit for performing train_test_spilit

# %%
# !pip install -U scikit-learn
from sklearn.model_selection import train_test_split
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Collecting scikit-learn
#   Downloading scikit_learn-1.7.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.22.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.16.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Downloading scikit_learn-1.7.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (9.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 62.5 MB/s eta 0:00:00
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.6.1
#     Uninstalling scikit-learn-1.6.1:
#       Successfully uninstalled scikit-learn-1.6.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sklearn-compat 0.1.3 requires scikit-learn<1.7,>=1.2, but you have scikit-learn 1.7.1 which is incompatible.
# Successfully installed scikit-learn-1.7.1

# %%
train_test_split(x,y,test_size = 0.1) # here we perform split and use 10% data of whole for testing
# Out:
# [     Stream_ID  Cgpa  Internships  Project
#  245        8.0  8.27          1.0      0.0
#  24         6.0  7.79          0.0      1.0
#  152        8.0  8.55          0.0      1.0
#  181        0.0  7.96          1.0      1.0
#  32         8.0  9.26          1.0      1.0
#  ..         ...   ...          ...      ...
#  372        3.0  8.93          1.0      1.0
#  215        4.0  8.23          0.0      1.0
#  40         1.0  7.95          1.0      1.0
#  111        3.0  7.25          0.0      0.0
#  162        5.0  7.52          0.0      1.0
#
#  [360 rows x 4 columns],
#       Stream_ID  Cgpa  Internships  Project
#  133        6.0  8.58          0.0      1.0
#  187        2.0  8.41          1.0      1.0
#  124        4.0  8.59          0.0      1.0
#  272        1.0  9.39          0.0      1.0
#  45         5.0  8.52          0.0      0.0
#  211        5.0  7.46          0.0      1.0
#  82         0.0  9.02          0.0      1.0
#  0          5.0  7.37          0.0      0.0
#  56         5.0  9.35          0.0      1.0
#  319        6.0  7.68          0.0      1.0
#  98         1.0  9.20          1.0      0.0
#  84         3.0  7.32          1.0      1.0
#  339        3.0  9.36          1.0      1.0
#  257        8.0  7.51          0.0      1.0
#  220        4.0  9.16          1.0      1.0
#  157        0.0  8.30          1.0      0.0
#  356        1.0  7.71          1.0      1.0
#  119       10.0  9.48          1.0      1.0
#  394       10.0  7.37          0.0      0.0
#  4          1.0  9.26          1.0      1.0
#  185        1.0  8.18          1.0      0.0
#  156        6.0  8.33          0.0      1.0
#  278        1.0  9.55          0.0      1.0
#  150        4.0  7.37          0.0      1.0
#  275        3.0  7.65          1.0      1.0
#  126        2.0  7.19          1.0      1.0
#  367       10.0  9.24          1.0      1.0
#  11         1.0  8.87          1.0      1.0
#  274        7.0  7.99          0.0      1.0
#  262        2.0  7.12          1.0      1.0
#  340        0.0  8.30          1.0      0.0
#  78         5.0  9.01          1.0      0.0
#  336        0.0  9.05          1.0      1.0
#  101        2.0  7.29          1.0      1.0
#  399        2.0  7.89          1.0      1.0
#  369        4.0  7.24          0.0      1.0
#  203        2.0  7.23          1.0      0.0
#  281        0.0  9.36          1.0      1.0
#  209       10.0  8.92          1.0      1.0
#  37         3.0  8.48          1.0      1.0
#  382        3.0  9.32          1.0      1.0,
#  245   -1.0
#  24     1.0
#  152    1.0
#  181    1.0
#  32     1.0
#        ...
#  372   -1.0
#  215   -1.0
#  40     1.0
#  111   -1.0
#  162    1.0
#  Name: Placement, Length: 360, dtype: float64,
#  133    1.0
#  187   -1.0
#  124   -1.0
#  272    1.0
#  45    -1.0
#  211   -1.0
#  82    -1.0
#  0     -1.0
#  56     1.0
#  319   -1.0
#  98    -1.0
#  84     1.0
#  339    1.0
#  257   -1.0
#  220    1.0
#  157   -1.0
#  356   -1.0
#  119    1.0
#  394   -1.0
#  4     -1.0
#  185   -1.0
#  156    1.0
#  278   -1.0
#  150    1.0
#  275    1.0
#  126   -1.0
#  367    1.0
#  11    -1.0
#  274   -1.0
#  262    1.0
#  340   -1.0
#  78    -1.0
#  336   -1.0
#  101   -1.0
#  399   -1.0
#  369    1.0
#  203   -1.0
#  281    1.0
#  209    1.0
#  37     1.0
#  382    1.0
#  Name: Placement, dtype: float64]

# %% [markdown]
# ## Above data we store in variable.

# %%
X_train , X_test , y_train , y_test = train_test_split(x,y,test_size = 0.1)

# %%
X_train
# Out:
#      Stream_ID  Cgpa  Internships  Project
# 353        7.0  8.22          0.0      0.0
# 142        4.0  7.99          0.0      1.0
# 147        9.0  8.88          1.0      1.0
# 214        5.0  9.16          1.0      0.0
# 174        4.0  7.90          1.0      1.0
# ..         ...   ...          ...      ...
# 237        4.0  7.93          0.0      1.0
# 293        1.0  9.60          1.0      1.0
# 372        3.0  8.93          1.0      1.0
# 192        3.0  9.34          0.0      1.0
# 24         6.0  7.79          0.0      1.0
#
# [360 rows x 4 columns]

# %%
y_train
# Out:
# 353   -1.0
# 142    1.0
# 147    1.0
# 214   -1.0
# 174    1.0
#       ...
# 237    1.0
# 293    1.0
# 372   -1.0
# 192   -1.0
# 24     1.0
# Name: Placement, Length: 360, dtype: float64

# %%
# scale our data
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train  = scaler.fit_transform(X_train)

# %%
X_train
# Out:
# array([[ 0.99140451, -0.06688796, -1.18321596, -1.68237657],
#        [-0.00553857, -0.11953362, -1.18321596,  0.57753226],
#        [ 1.65603324,  0.08418219,  0.84515425,  0.57753226],
#        ...,
#        [-0.33785293,  0.0956269 ,  0.84515425,  0.57753226],
#        [-0.33785293,  0.1894735 , -1.18321596,  0.57753226],
#        [ 0.65909015, -0.16531245, -1.18321596,  0.57753226]])

# %%
X_test = scaler.fit_transform(X_test)

# %%
X_test
# Out:
# array([[ 1.61829246, -0.38969389, -0.92932038,  0.75955453],
#        [-0.64363905,  0.68473903,  1.07605517, -1.31656118],
#        [ 0.48732671, -0.7815459 , -0.92932038,  0.75955453],
#        [ 1.99528104,  1.10187181, -0.92932038, -1.31656118],
#        [-0.26665046,  1.74653157,  1.07605517,  0.75955453],
#        [-0.64363905,  1.54428537,  1.07605517, -1.31656118],
#        [-1.02062763,  0.97546794,  1.07605517,  0.75955453],
#        [-0.64363905, -0.92059016,  1.07605517,  0.75955453],
#        [-0.64363905, -0.80682668,  1.07605517,  0.75955453],
#        [ 1.24130387,  0.520414  , -0.92932038,  0.75955453],
#        [-0.64363905, -1.07227481,  1.07605517, -1.31656118],
#        [ 0.86431529,  0.28024664, -0.92932038,  0.75955453],
#        [ 0.48732671, -0.70570358, -0.92932038,  0.75955453],
#        [ 1.24130387,  0.71001981, -0.92932038,  0.75955453],
#        [-1.02062763,  1.45580266,  1.07605517,  0.75955453],
#        [-0.26665046, -2.94305214, -0.92932038, -1.31656118],
#        [-0.64363905,  0.48249283,  1.07605517, -1.31656118],
#        [ 0.11033812, -0.89530939, -0.92932038,  0.75955453],
#        [-0.64363905,  1.13979298,  1.07605517, -1.31656118],
#        [-1.02062763, -1.14811713,  1.07605517, -1.31656118],
#        [ 0.48732671,  0.33080819, -0.92932038,  0.75955453],
#        [-0.64363905, -0.59194009,  1.07605517, -1.31656118],
#        [-0.64363905,  1.63276808, -0.92932038,  0.75955453],
#        [ 0.86431529, -0.50345738, -0.92932038,  0.75955453],
#        [-1.39761621,  1.05131026, -0.92932038, -1.31656118],
#        [ 1.24130387, -0.25064963, -0.92932038,  0.75955453],
#        [ 1.24130387, -0.37705351, -0.92932038,  0.75955453],
#        [-1.02062763,  0.15384276,  1.07605517,  0.75955453],
#        [ 0.86431529, -0.83210745, -0.92932038,  0.75955453],
#        [ 1.99528104,  0.44457167, -0.92932038,  0.75955453],
#        [-1.39761621, -0.87002861,  1.07605517, -1.31656118],
#        [-0.26665046, -0.93323055,  1.07605517,  0.75955453],
#        [ 0.48732671, -0.60458048, -0.92932038,  0.75955453],
#        [-0.64363905, -1.21131907,  1.07605517,  0.75955453],
#        [ 1.61829246,  1.08923143,  1.07605517,  0.75955453],
#        [-1.39761621,  0.20440431, -0.92932038,  0.75955453],
#        [-0.26665046, -1.16075752, -0.92932038, -1.31656118],
#        [-0.26665046,  1.30411801,  1.07605517,  0.75955453],
#        [ 1.24130387,  0.520414  , -0.92932038, -1.31656118],
#        [-1.39761621, -0.35177273, -0.92932038, -1.31656118],
#        [-0.64363905, -0.02312266,  1.07605517, -1.31656118]])

# %% [markdown]
# Using Logistic Regression We made our data ( ye aisa line khojega jo classes ko bat dega )

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %%
clf.fit(X_train , y_train)
# Out:
# LogisticRegression()

# %%
y_pred = clf.predict(X_test)

# %%
y_test
# Out:
# 258    1.0
# 312   -1.0
# 211   -1.0
# 95    -1.0
# 71    -1.0
# 94    -1.0
# 30     1.0
# 196    1.0
# 96     1.0
# 226    1.0
# 203   -1.0
# 221   -1.0
# 162    1.0
# 225   -1.0
# 53     1.0
# 63    -1.0
# 89    -1.0
# 150    1.0
# 29    -1.0
# 18    -1.0
# 167    1.0
# 234   -1.0
# 338    1.0
# 319   -1.0
# 59    -1.0
# 41     1.0
# 97     1.0
# 70     1.0
# 130   -1.0
# 115    1.0
# 256   -1.0
# 164    1.0
# 62     1.0
# 262    1.0
# 168   -1.0
# 233    1.0
# 320   -1.0
# 170    1.0
# 75    -1.0
# 298   -1.0
# 355   -1.0
# Name: Placement, dtype: float64

# %%
# now we see accuracy
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test , clf.predict(X_test)) # by this we can see our model accuracy
# Out:
# 0.8292682926829268

# %%
from mlxtend.plotting import plot_decision_regions
# i can't able to perform decision plot , in future i will add it

# %%
sns.scatterplot(x = New_data["Stream_ID"] , y = New_data["Cgpa"] , hue = New_data["Internships"] , style = New_data["Project"] )
# Out:
# <Axes: xlabel='Stream_ID', ylabel='Cgpa'>

# %%
import pickle

# %%
pickle.dump(clf,open('placement_model.pkl' , "wb"))
